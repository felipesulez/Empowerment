# %% [markdown]
# ## Second Exercise

# %% [markdown]
# This exercise is created in Jupyter Notebook using two libraries of Python (pandas and numpy). They are being used to visualize the first inference data. Along the script, four questions were answered. To better understand, the code is written to express clearly ideas using notes that contain in their own answers dashboard.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading Data

# %%
path = '/Users/felipesulez/Documents/Emporwerment/DataSets/astronauts.csv'
data = pd.read_csv(path)
df_copy = data.copy() # Copy of DataFrame data

# %%
df_copy.head(750)
# Out:
#     s.no/code given          Astronaut name                    country  \
# 0               612             Cameron Bess  United States of America
# 1               611                Lane Bess  United States of America
# 2               610                Evan Dick  United States of America
# 3               609             Dylan Taylor  United States of America
# 4               608          Michael Strahan  United States of America
# ..              ...                      ...                       ...
# 745              86          Vitaly Zholobov                      USSR
# 746            A111      Some Tortoises (#3)                      USSR
# 747            A110        Unknown Zebrafish                      USSR
# 748            A109  Twenty-five Wistar Rats                      USSR
# 749            A108      Some Tortoises (#2)                      USSR
#
#     company space agency missions days in space spacewalks days spacewalking  \
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 952 entries, 0 to 951
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   s.no/code given       942 non-null    object
#  1   Astronaut name        952 non-null    object
#  2   country               952 non-null    object
#  3   company space agency  629 non-null    object
#  4   missions              952 non-null    object
#  5   days in space         621 non-null    object
#  6   spacewalks            621 non-null    object
#  7   days spacewalking     621 non-null    object
#  8   acheivement 1         734 non-null    object
#  9   acheivement 2         403 non-null    object
#  10  acheivement 3         215 non-null    object
#  11  acheivement 4         331 non-null    object
#  12  still in space        10 non-null     object
# dtypes: object(13)
# memory usage: 96.8+ KB

# %%
df_copy.dtypes
# Out:
# s.no/code given         object
# Astronaut name          object
# country                 object
# company space agency    object
# missions                object
# days in space           object
# spacewalks              object
# days spacewalking       object
# acheivement 1           object
# acheivement 2           object
# acheivement 3           object
# acheivement 4           object
# still in space          object
# dtype: object

# %%
df_copy.isnull().sum()
# Out:
# s.no/code given          10
# Astronaut name            0
# country                   0
# company space agency    323
# missions                  0
# days in space           331
# spacewalks              331
# days spacewalking       331
# acheivement 1           218
# acheivement 2           549
# acheivement 3           737
# acheivement 4           621
# still in space          942
# dtype: int64
